# %%
import pandas as pd
import numpy as np
Energy = pd.read_excel('Energy Indicators.xls',sheet_name='Energy',header=16,skipfooter=38).drop([0]).drop(['Unnamed: 1','Unnamed: 0'],axis=1)
Energy = Energy.rename(columns={'Unnamed: 2':'Country','Renewable Electricity Production':'% Renewable'})
Energy=Energy.replace(r'\.\.\.', np.nan, regex=True)
def change_name(row):
    if row['Country']== 'Republic of Korea':
        row['Country']= 'South Korea'
    if row['Country']== 'United States of America':
        row['Country']= 'United States'
    if row['Country']== 'United Kingdom of Great Britain and Northern Ireland':
        row['Country']= 'United Kingdom'
    if row['Country']== 'China, Hong Kong Special Administrative Region':
        row['Country']= 'Hong Kong'
    return row
Energy['Energy Supply']=Energy.apply(lambda x:x['Energy Supply']*1000000,axis='columns')
Energy = Energy.replace(r'(\s\(.*?\))|(\d)',value='',regex=True)
Energy = Energy.apply(change_name,axis='columns')
GDP = pd.read_csv('world_bank.csv',header=4)
def change_name2(row):
    if row['Country Name']== 'Korea, Rep.':
        row['Country Name']= 'South Korea'
    if row['Country Name']=='Iran, Islamic Rep.':
        row['Country Name']= 'Iran'
    if row['Country Name']== 'Hong Kong SAR, China':
        row['Country Name']= 'Hong Kong'
    return row

GDP = GDP.apply(change_name2, axis='columns')
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn = ScimEn.iloc[0:15]
merge1 = pd.merge(ScimEn,Energy, how='inner',on='Country')
years = ['Country Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
GDP = GDP[years]
#DataFrame = pd.merge(merge1,GDP,how='inner',left_index=True,right_index=True)

# %%
merge1
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
merge1.set_index('Country')
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
GDP.rename(columns={'Country Name':'Country'},inplace=True)
GDP.set_index('Country')
# Out:
#                           2006          2007          2008          2009  \
# Country
# Aruba                      NaN           NaN           NaN           NaN
# Andorra           4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan       1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola            5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania           9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ...                        ...           ...           ...           ...
# Yemen, Rep.       2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# South Africa      3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# Zambia            1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# Zimbabwe          1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#                           2010          2011          2012          2013  \
# ...

# %%
DataFrame = pd.merge(merge1,GDP).set_index('Country')

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
years2 = ['2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']

# %%
#my_categories = pd.CategoricalDtype(ordered=True)

avgGDP = DataFrame[years2].mean(axis=1)

# %%
avgGDP
# Out:
# Country
# China                 6.348609e+12
# United States         1.536434e+13
# Japan                 5.542208e+12
# United Kingdom        2.487907e+12
# Russian Federation    1.565459e+12
# Canada                1.660647e+12
# Germany               3.493025e+12
# India                 1.769297e+12
# France                2.681725e+12
# South Korea           1.106715e+12
# Italy                 2.120175e+12
# Spain                 1.418078e+12
# Iran                  4.441558e+11
# Australia             1.164043e+12
# Brazil                2.189794e+12
# dtype: float64

# %%
avgGDP.sort_values(ascending=False,inplace=True)

# %%
avgGDP
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
rate6thGDP = DataFrame['2015'].iloc[3]/DataFrame['2006'].iloc[3]

# %%
rate6thGDP
# Out:
# 1.1019588220774517

# %%
mean_energy_per_capita = DataFrame['Energy Supply per capita'].mean()

# %%
mean_energy_per_capita
# Out:
# 157.6

# %%
max_RenPer = (DataFrame['% Renewable'].idxmax(axis=0, skipna=True),DataFrame['% Renewable'].max())

# %% [markdown]
# max_RenPer

# %%
max_RenPer
# Out:
# ('Brazil', 69.64803)

# %%
#def ratio_column(row):
 #   row['New']= row['Self-Citations']/row['Citations']
  #  return row
#DataFrame.apply(ratio_column)
DataFrame['Ratio citations']= DataFrame['Self-citations']/DataFrame['Citations']

# %%
max_Ratio = (DataFrame['Ratio citations'].idxmax(axis=0, skipna=True),DataFrame['Ratio citations'].max())

# %%
max_Ratio
# Out:
# ('China', 0.6893126179389422)

# %%
Est_Population= DataFrame['Energy Supply']/DataFrame['Energy Supply per capita']

# %%
Est_Population
# Out:
# Country
# China                 1.367645e+09
# United States         3.176154e+08
# Japan                 1.274094e+08
# United Kingdom        6.387097e+07
# Russian Federation    1.435000e+08
# Canada                3.523986e+07
# Germany               8.036970e+07
# India                 1.276731e+09
# France                6.383735e+07
# South Korea           4.980543e+07
# Italy                 5.990826e+07
# Spain                 4.644340e+07
# Iran                  7.707563e+07
# Australia             2.331602e+07
# Brazil                2.059153e+08
# dtype: float64

# %%
Est_Population.sort_values(ascending=False,inplace=True)

# %%
Est_Population
# Out:
# Country
# China                 1.367645e+09
# India                 1.276731e+09
# United States         3.176154e+08
# Brazil                2.059153e+08
# Russian Federation    1.435000e+08
# Japan                 1.274094e+08
# Germany               8.036970e+07
# Iran                  7.707563e+07
# United Kingdom        6.387097e+07
# France                6.383735e+07
# Italy                 5.990826e+07
# South Korea           4.980543e+07
# Spain                 4.644340e+07
# Canada                3.523986e+07
# Australia             2.331602e+07
# dtype: float64

# %%
Est_P3th = Est_Population.index[2]

# %%
Est_P3th
# Out:
# 'United States'

# %%
DataFrame['Est Population']= Est_Population

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
DataFrame['Citable Docs per capita']=DataFrame['Est Population']/DataFrame['Citable documents']

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
corr = DataFrame['Energy Supply per capita'].corr(DataFrame['Citable Docs per capita'])

# %%
corr
# Out:
# -0.5838221986852355

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# United States        2.0    96661.0            94747.0   792274.0
# Japan                3.0    30504.0            30287.0   223024.0
# United Kingdom       4.0    20944.0            20357.0   206091.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# Canada               6.0    17899.0            17620.0   215003.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# France               9.0    13153.0            12973.0   130632.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Italy               11.0    10964.0            10794.0   111850.0
# Spain               12.0     9428.0             9330.0   123336.0
# Iran                13.0     8896.0             8819.0    57470.0
# ...

# %%
DataFrame['Est Population']/DataFrame['Citable documents']
# Out:
# Country
# China                 10788.652893
# United States          3352.247402
# Japan                  4206.735430
# United Kingdom         3137.543240
# Russian Federation     7841.101579
# Canada                 1999.992331
# Germany                4775.099339
# India                 86027.273717
# France                 4920.785431
# South Korea            4177.256552
# Italy                  5550.144236
# Spain                  4977.855973
# Iran                   8739.724487
# Australia              2672.322902
# Brazil                23954.775970
# dtype: float64

# %%
DataFrame['Citable Docs per capita'].corr(DataFrame['Energy Supply per capita'])
# Out:
# -0.5838221986852355

# %%
def plot9():
    import matplotlib as plt
    # %matplotlib inline
    
    Top15 = DataFrame
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
    Top15.plot(x='Citable docs per Capita', y='Energy Supply per Capita', kind='scatter', xlim=[0, 0.0006])

# %%
def median_Ren(row):
    median = DataFrame['% Renewable'].median()
    if row['% Renewable']> median:
        row['High Renew']= 1
    else:
        row['High Renew']=0
    return row

# %%
DataFrame=DataFrame.apply(median_Ren,axis='columns')

# %%
HighRenew = DataFrame['High Renew']

# %%
HighRenew
# Out:
# Country
# China                 1.0
# United States         0.0
# Japan                 0.0
# United Kingdom        0.0
# Russian Federation    1.0
# Canada                1.0
# Germany               1.0
# India                 0.0
# France                0.0
# South Korea           0.0
# Italy                 1.0
# Spain                 1.0
# Iran                  0.0
# Australia             0.0
# Brazil                1.0
# Name: High Renew, dtype: float64

# %%
ans10=HighRenew.sort_values(ascending=False)

# %%
ans10
# Out:
# Country
# Brazil                1.0
# Spain                 1.0
# Italy                 1.0
# Germany               1.0
# Canada                1.0
# Russian Federation    1.0
# China                 1.0
# Australia             0.0
# Iran                  0.0
# South Korea           0.0
# France                0.0
# India                 0.0
# United Kingdom        0.0
# Japan                 0.0
# United States         0.0
# Name: High Renew, dtype: float64

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
def continent(row):
    row['Continent']=ContinentDict[row.name]
    return row

DataFrame =DataFrame.apply(continent,axis='columns')

# %%
ContinentDict['China']
# Out:
# 'Asia'

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# United States        2.0    96661.0            94747.0   792274.0
# Japan                3.0    30504.0            30287.0   223024.0
# United Kingdom       4.0    20944.0            20357.0   206091.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# Canada               6.0    17899.0            17620.0   215003.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# France               9.0    13153.0            12973.0   130632.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Italy               11.0    10964.0            10794.0   111850.0
# Spain               12.0     9428.0             9330.0   123336.0
# Iran                13.0     8896.0             8819.0    57470.0
# ...

# %%
Continents_Data=DataFrame.groupby("Continent").agg({'Est Population':(np.size,np.sum,np.mean,np.std)})

# %%
Continents_Data
# Out:
#               Est Population
#                         size           sum          mean           std
# Continent
# Asia                     5.0  2.898666e+09  5.797333e+08  6.790979e+08
# Australia                1.0  2.331602e+07  2.331602e+07           NaN
# Europe                   6.0  4.579297e+08  7.632161e+07  3.464767e+07
# North America            2.0  3.528552e+08  1.764276e+08  1.996696e+08
# South America            1.0  2.059153e+08  2.059153e+08           NaN

# %%
DataFrame
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# United States        2.0    96661.0            94747.0   792274.0
# Japan                3.0    30504.0            30287.0   223024.0
# United Kingdom       4.0    20944.0            20357.0   206091.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# Canada               6.0    17899.0            17620.0   215003.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# France               9.0    13153.0            12973.0   130632.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Italy               11.0    10964.0            10794.0   111850.0
# Spain               12.0     9428.0             9330.0   123336.0
# Iran                13.0     8896.0             8819.0    57470.0
# ...

# %%
bins=pd.cut(DataFrame['% Renewable'],5)

# %%
bins
# Out:
# Country
# China                 (15.753, 29.227]
# United States          (2.212, 15.753]
# Japan                  (2.212, 15.753]
# United Kingdom         (2.212, 15.753]
# Russian Federation    (15.753, 29.227]
# Canada                (56.174, 69.648]
# Germany               (15.753, 29.227]
# India                  (2.212, 15.753]
# France                (15.753, 29.227]
# South Korea            (2.212, 15.753]
# Italy                 (29.227, 42.701]
# Spain                 (29.227, 42.701]
# Iran                   (2.212, 15.753]
# Australia              (2.212, 15.753]
# Brazil                (56.174, 69.648]
# Name: % Renewable, dtype: category
# Categories (5, interval[float64]): [(2.212, 15.753] < (15.753, 29.227] < (29.227, 42.701] < (42.701, 56.174] < (56.174, 69.648]]

# %%
Multi_Data = DataFrame.groupby(['Continent',bins])["% Renewable"].size()

# %%
Continents_Ren
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-f099b9e2e1a6> in <module>
# ----> 1 Continents_Ren
#
# NameError: name 'Continents_Ren' is not defined

# %%
Multi_Data
# Out:
# Continent      % Renewable
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Australia      (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# North America  (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    1
# South America  (2.212, 15.753]     0
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
# ...

# %%
Multi_Data.index.names = ('Continent','% Renewable')

# %%
Multi_Data
# Out:
# Continent      % Renewable
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Australia      (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# North America  (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    1
# South America  (2.212, 15.753]     0
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
# ...

# %%
Multi_Data[Multi_Data!=0]
# Out:
# Continent      % Renewable
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
# Australia      (2.212, 15.753]     1
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
# North America  (2.212, 15.753]     1
#                (56.174, 69.648]    1
# South America  (56.174, 69.648]    1
# Name: % Renewable, dtype: int64

# %%
Final=pd.Series(DataFrame['Est Population']).map('{:,}'.format)

# %%
Final
# Out:
# Country
# China                 1,367,645,161.2903225
# United States          317,615,384.61538464
# Japan                  127,409,395.97315437
# United Kingdom         63,870,967.741935484
# Russian Federation            143,500,000.0
# Canada                  35,239,864.86486486
# Germany                 80,369,696.96969697
# India                 1,276,730,769.2307692
# France                  63,837,349.39759036
# South Korea            49,805,429.864253394
# Italy                  59,908,256.880733944
# Spain                    46,443,396.2264151
# Iran                    77,075,630.25210084
# Australia              23,316,017.316017315
# Brazil                 205,915,254.23728815
# Name: Est Population, dtype: object

# %%
def plot9():
    import matplotlib as plt
    # %matplotlib inline
    
    Top15 = answer_one()
    Top15['PopEst'] = Top15['Energy Supply'] / Top15['Energy Supply per Capita']
    Top15['Citable docs per Capita'] = Top15['Citable documents'] / Top15['PopEst']
    Top15.plot(x='Citable docs per Capita', y='Energy Supply per Capita', kind='scatter', xlim=[0, 0.0006])

# %%
def plot_optional():
    import matplotlib as plt
    # %matplotlib inline
    Top15 = answer_one()
    ax = Top15.plot(x='Rank', y='% Renewable', kind='scatter', 
                    c=['#e41a1c','#377eb8','#e41a1c','#4daf4a','#4daf4a','#377eb8','#4daf4a','#e41a1c',
                       '#4daf4a','#e41a1c','#4daf4a','#4daf4a','#e41a1c','#dede00','#ff7f00'], 
                    xticks=range(1,16), s=6*Top15['2014']/10**10, alpha=.75, figsize=[16,6]);

    for i, txt in enumerate(Top15.index):
        ax.annotate(txt, [Top15['Rank'][i], Top15['% Renewable'][i]], ha='center')

    print("This is an example of a visualization that can be created to help understand the data. \
This is a bubble chart showing % Renewable vs. Rank. The size of the bubble corresponds to the countries' \
2014 GDP, and the color corresponds to the continent.")
